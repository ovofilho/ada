# %%
def listar_restaurantes(restaurantes):
    print('=' * 50)
    opcao_invalida = True
    for i in restaurantes:
        print(f"Codigo do restaurante: {i[0]}\tNome do restaurante: {i[1]}") 
    print('=' * 50)
    while opcao_invalida:
        print('=' * 22, 'Deseja Mostrar o Cardápio?', '=' * 22)
        print('''
        1 - Informar restaurante para mostrar cardapio
        0 - Voltar
        ''')
        print('=' *50)
        opcao = int(input('Digite uma opção: '))
        opcao_invalida = opcao not in [0,1]
        if opcao_invalida:
            print("Voce digitou uma opcao invalida")   
        else:
            listar_cardapio = opcao == 1
            if listar_cardapio:
                codigo_restaurante = int(input("Digite o código do restaurante para mostrar o cardápio:"))
                encontrado,restaurante = localizar_restaurante(restaurantes,codigo_restaurante)
                if encontrado:
                    return listar_cardapio(restaurante, cardapio)
                else:
                    print(f"Restaurante de código {codigo_restaurante} não foi localizado.")
                    
            else:
                opcao_invalida = False

# %%
def listar_cardapio(restaurante,cardapio):
    codigo_restaurante = restaurante[0]
    listagem_cardapio = []
    print(f"Listando o cardápio do restaurante {codigo_restaurante}")
    for i in cardapio:
        restaurante_no_cardapio = i[0] == restaurante[0]
        if restaurante_no_cardapio:
            listagem_cardapio.append(i[1])
    #for i in listagem_cardapio:
        #print(f"\nNome do produto: {i[0]}\nPreço: {i[1]}\nTempo: {i[2]}\n")
        #print('=' * 50)
    return listagem_cardapio

# %%
def fazer_pedido(restaurantes, cardapio, pedidos):
    listagem_cardapio = listar_restaurantes(restaurantes,cardapio)
    continua_pedido = True
    while continua_pedido:
        print(listagem_cardapio)
        opcao = input("Deseja continuar o pedido? (S/N)")
        continua_pedido = opcao.upper() == "S"
        if continua_pedido:
            produto = int(input("Digite o código do produto:"))
            quantidade = int(input("Digite a quantidade do produto:"))

# %%
'''while opcao_invalida:
        print('\n')
        print('=' * 50)
        print("Deseja tentar novamente?")
        print('=' * 50)
        print('''
        1 - Sim
        0 - Não
      ''')
        opcao = int(input('Digite uma opção: '))
        opcao_invalida = opcao not in [1,0]
        if opcao_invalida:
            print("Voce digitou uma opcao invalida")
        if opcao == 1:
            func_listar_restaurantes()

continuar = True

while continuar:
    opcao = menu_inicial()
    continuar = opcao!=0
    cadastrar_restaurante_cardapio = opcao==1
    listar_restaurante = opcao==2
    fazer_pedido = opcao==3
    consultar_pedido = opcao==4

    while cadastrar_restaurante_cardapio:
        opcao1 = menu_1()
        cadastrar_restaurante_cardapio = opcao1!=0
        cadastrar_restaurante = opcao1==1
        cadastrar_cardapio = opcao1==2

        while cadastrar_restaurante:
            func_cadastrar_restaurante(restaurantes)
            cadastrar_restaurante = False

        while cadastrar_cardapio:
            func_cadastrar_cardapio(cardapio)
            cadastrar_cardapio = False

    while listar_restaurante:
        func_listar_restaurantes()
        listar_restaurante = False

    while fazer_pedido:
        #o programa vai para uma tela que lista todos os restaurantes e pede para
        #usuário escolher um. Depois ele lista um cardápio e pergunta se o usuario
        #quer continuar com o pedido.
        #Para cada novo produto o programa vai adicionar o novo codigo na matriz.
        #Quando o pedido for finalizado, o programa deve informar o código do pedido e o
        #tempo do maior produto adicionado. logo após o programa vai retornar para o menu principal.
        pass

    while consultar_pedido:
        #na opção consultar pedido o programa vai
        #perguntar o código do pedido e listar a matriz relacionada a ele
        pass





print(restaurantes)
print(cardapio)
print(pedido)'''

# %%
def cadastrar_cardapio(restaurantes,cardapio):
    opcao_invalida = True
    codigo_restaurante = int(input('Codigo do restaurante'))
    encontrou,restaurante = localizar_restaurante(restaurantes,codigo_restaurante)
    if encontrou:
        nome_do_produto = input('Digite o Nome produto')
        preco_produto = input('Digite o Preço Produto')
        tempo_preparo = input('Digite o Tempo preparo')
        print(f'{nome_do_produto} por {preco_produto} com  tempo de preparo {tempo_preparo} foi adicionado no restaurante {restaurante[1]}')
        cardapio.append([codigo_restaurante,[nome_do_produto, preco_produto, tempo_preparo]])
    else:
        print("O codigo do de restaurante é invalido")
    while opcao_invalida:
        print('\n')
        print('=' * 50)
        print("Deseja cadastrar outro produto?")
        print('=' * 50)
        print('''
        1 - Sim
        0 - Não
      ''')
        opcao = int(input('Digite uma opção: '))
        opcao_invalida = opcao not in [1,0]
        if opcao_invalida:
            print("Voce digitou uma opcao invalida")
        else:
            repetir = opcao == 1
            if repetir:
                cadastrar_cardapio(cardapio)
            else:
                opcao_invalida = False

# %%
def localizar_restaurante(restaurantes, codigo_restaurante):
    restaurante_encontrado = False
    for i in restaurantes:
        restaurante_encontrado  = codigo_restaurante == i[0]
        if restaurante_encontrado:
            return True,i
        else:
            print("Código não localizado.")
            return False,None
#restaurantes = []
#cadastrar_restaurante(restaurantes)
#print(localizar_restaurante(restaurantes,0))
#print(localizar_restaurante(restaurantes,50))

# %%
def cadastrar_restaurante(restaurantes):
    contador = len(restaurantes) #o contador já é o proximo espaço, pois o ultimo é len -1
    opcao_invalida = True
    print('=' * 50)
    restaurante_adicionado = input('Digite o nome do restaurante a ser adicionado: ')
    print('=' * 50)
    
    restaurantes.append([contador, restaurante_adicionado])
    print(f'O restaurante {restaurante_adicionado} foi adicionado com sucesso\nDeseja adicionar mais algum restaurante?')
    while opcao_invalida:
        print('=' * 50)
        print('''
        1 - Sim
        0 - Não
      ''')
        opcao = int(input('Digite uma opção: '))
        opcao_invalida = opcao not in [1,0]
        if opcao_invalida:
            print("Voce digitou uma opcao invalida")
        else:
            repetir = opcao == 1
            if repetir:
                func_cadastrar_restaurante(restaurantes)
            else:
                opcao_invalida = False

# %%
def menu_cadastrar():
   #opcao_valida = opcao > 0 and opcao <= 4
    opcao_invalida = True
    lista_opcoes = [0,1,2]
    while opcao_invalida:
        print('=' * 22, 'Menu Cadastrar', '=' * 22)
        print('''
        1 - Cadastrar restaurante
        2 - Cadastar cardápio
        0 - Voltar
        ''')
        print('=' *50)
        opcao_cadastrar = int(input('Digite uma opção: '))
        opcao_invalida = opcao1 not in lista_opcoes
        if opcao_invalida:
            print("Voce digitou uma opcao invalida")
    return opcao_cadastrar
menu_cadastrar()

# %%
def menu_inicial():
   #opcao_valida = opcao > 0 and opcao <= 4
    opcao_invalida = True
    lista_opcoes = [0,1,2,3,4]
    while opcao_invalida:
        print('=' * 22, 'Menu 1', '=' * 22)
        print('''
        1 - Cadastrar restaurante/cardápio
        2 - Listar restaurante/cardápio
        3 - Fazer pedido
        4 - Consultar pedido
        0 - Sair
        ''')
        print('=' *50)
        opcao = int(input('Digite uma opção: '))
        opcao_invalida = opcao not in lista_opcoes
        if opcao_invalida:
            print("Voce digitou uma opcao invalida")
    return opcao
